# %% [markdown]
# <a href="https://colab.research.google.com/github/TheTharz/LLM/blob/main/Code_llama_2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install dependencies
# !pip install transformers --quiet

# %%
from huggingface_hub import login
login()  # paste your HF token if needed

# %%
# Step 2: Import necessary library
from transformers import pipeline

# Step 3: Load the zero-shot-classification model
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# Device set to use cuda:0

# %%
# Step 4: Define the code snippet to analyze
code_snippet = "import os; while;"

# Step 5: Define candidate labels
labels = ["malicious", "safe"]

# Step 6: Run classification
result = classifier(code_snippet, labels)

# Step 7: Display result
import pandas as pd
pd.DataFrame({
    "Label": result["labels"],
    "Score": result["scores"]
})
# Out:
#        Label     Score
# 0       safe  0.775076
# 1  malicious  0.224924
